# %% [markdown]
# <a href="https://colab.research.google.com/github/priyu283/DN5-Java-FSE-DeepSkilling/blob/main/Day2_q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS

reviews = [
    "This laptop is lightweight and performs very well.",
    "Battery life is poor, but the display is amazing.",
    "Excellent performance with great battery backup.",
    "I did not like the keyboard quality."
]


cleaned_reviews = []

for review in reviews:

    review = review.lower()


    review = review.translate(str.maketrans('', '', string.punctuation))


    words = review.split()


    words = [word for word in words if word not in ENGLISH_STOP_WORDS]


    cleaned_review = " ".join(words)
    cleaned_reviews.append(cleaned_review)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(cleaned_reviews)


print("Cleaned Reviews:\n")
for review in cleaned_reviews:
    print(review)

print("\nTF-IDF Feature Names:\n")
print(vectorizer.get_feature_names_out())

print("\nTF-IDF Matrix:\n")
print(tfidf_matrix.toarray())
# Out:
# Cleaned Reviews:
#
# laptop lightweight performs
# battery life poor display amazing
# excellent performance great battery backup
# did like keyboard quality
#
# TF-IDF Feature Names:
#
# ['amazing' 'backup' 'battery' 'did' 'display' 'excellent' 'great'
#  'keyboard' 'laptop' 'life' 'lightweight' 'like' 'performance' 'performs'
#  'poor' 'quality']
#
# TF-IDF Matrix:
#
# [[0.         0.         0.         0.         0.         0.
#   0.         0.         0.57735027 0.         0.57735027 0.
#   0.         0.57735027 0.         0.        ]
#  [0.46516193 0.         0.36673901 0.         0.46516193 0.
#   0.         0.         0.         0.46516193 0.         0.
#   0.         0.         0.46516193 0.        ]
#  [0.         0.46516193 0.36673901 0.         0.         0.46516193
#   0.46516193 0.         0.         0.         0.         0.
#   0.46516193 0.         0.         0.        ]
#  [0.         0.         0.         0.5        0.         0.
# ...
